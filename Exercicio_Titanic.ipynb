# %% [markdown]
# <h2><u><font face=”Times New Roman” color=”blue”>Python para Data Science - Faculdade Impacta</font></h2></u>
#
# <h2><u><font face=”Times New Roman”>Manipulando o Dataset Titanic</h2></u></font>

# %%
#importando a biblioteca do pandas (https://pandas.pydata.org/)
import pandas as pd

# %%
#metodo responsavel por realizar a leitura do arquivo
titanic_df = pd.read_csv  ('C:\FCD\datasets/titanic.csv')

# %%
#abrindo dataset titanic
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#leitura as 15 primeiras linhas do dataset
titanic_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#Exibi estrutura do arquivo, quantidade de linhas e colunas 
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# <h3>Exercicio</h3>
#
# 1 - com o shape, podemos avaliar a estrutura do arquivo. Repare na resposta que ele parece um array. Imagine que gostariamos apenas de retornar a quantidade de linhas, como podemos fazer?
#
# 2 - com o metodo head, retornamos a quantiade de linhas do arquivo de cima para baixo, se queremos de baixo para cima, executamos o metodo tail. Execute ele.

# %%
titanic_df.shape[0]
# Out:
# 891

# %%
#Retorna as linhas de baixo para cima
titanic_df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Retorna as informações estatisticas do arquivo
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
round((titanic_df.isnull().sum()) * 100 / titanic_df.shape[0],2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <h3><u>Exercicio</h3></u>
#
# 1 - tire a porcentagem de dados nulos

# %%
titanic_df.loc[titanic_df.Survived >= 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
titanic_df.loc[:70].head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
novo_titanic_df = titanic_df.loc[(titanic_df.Sex == 'male') & (titanic_df.Age > 35)]

# %%
novo_titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 13            14         0       3
# 30            31         0       1
# 33            34         0       2
# 35            36         0       1
# 54            55         0       1
# 62            63         0       1
# 92            93         0       1
# 94            95         0       3
# 96            97         0       1
# 104          105         0       3
# 108          109         0       3
# 110          111         0       1
# 116          117         0       3
# 124          125         0       1
# 129          130         0       3
# 137          138         0       1
# 148          149         0       2
# 149          150         0       2
# 150          151         0       2
# 152          153         0       3
# 153          154         0       3
# 155          156         0       1
# 160          161         0       3
# 170          171         0       1
# ...

# %% [markdown]
# <h3><u>Exercicio</h3></u>
#
# 1 - Nesta etapa quero que vc crie um novo dataframe, uma variavel, ela só poderá ter pessoas do sexo masculino e que tenham mais que 35 anos de idade.

# %%
#Renomear nome das colunas
titanic_df = titanic_df.rename(columns={"Age": "idade"})

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# Depois de executar o metodo de rename, e agora executar o metodo head, vimos que a coluna Age não mudou o nome, porque?

# %% [markdown]
# <h3><u>Exercicio</h3></u>
#
# Renomei todas as colunas, conforme seu entendimento
# Muita das vezes vamos querer deletar uma coluna do nosso dataset, podemos fazer isso usando o metodo drop

# %%
#drop
titanic_df.drop('Name', axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex  idade  SibSp  Parch  \
# 0              1         0       3    male   22.0      1      0
# 1              2         1       1  female   38.0      1      0
# 2              3         1       3  female   26.0      0      0
# 3              4         1       1  female   35.0      1      0
# 4              5         0       3    male   35.0      0      0
# 5              6         0       3    male    NaN      0      0
# 6              7         0       1    male   54.0      0      0
# 7              8         0       3    male    2.0      3      1
# 8              9         1       3  female   27.0      0      2
# 9             10         1       2  female   14.0      1      0
# 10            11         1       3  female    4.0      1      1
# 11            12         1       1  female   58.0      0      0
# 12            13         0       3    male   20.0      0      0
# 13            14         0       3    male   39.0      1      5
# ...

# %% [markdown]
# <h3><u>Exercicio</h3></u>
#
# Crie um novo dataframe, porém somente com as colunas: Survived, Pclass, Sex, Age, Ticket, Embarked

# %%
titanic_df_novo = titanic_df[['Survived', 'Pclass', 'Sex', 'idade', 'Ticket', 'Embarked']]

# %%
titanic_df_novo
# Out:
#      Survived  Pclass     Sex  idade            Ticket Embarked
# 0           0       3    male   22.0         A/5 21171        S
# 1           1       1  female   38.0          PC 17599        C
# 2           1       3  female   26.0  STON/O2. 3101282        S
# 3           1       1  female   35.0            113803        S
# 4           0       3    male   35.0            373450        S
# 5           0       3    male    NaN            330877        Q
# 6           0       1    male   54.0             17463        S
# 7           0       3    male    2.0            349909        S
# 8           1       3  female   27.0            347742        S
# 9           1       2  female   14.0            237736        C
# 10          1       3  female    4.0           PP 9549        S
# 11          1       1  female   58.0            113783        S
# 12          0       3    male   20.0         A/5. 2151        S
# 13          0       3    male   39.0            347082        S
# ...

# %%
#Com o metodo unique, podemos retornar apenas os dados unicos de uma determinada Serie.
titanic_df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
#Com o value_counts, podemos retornar q quantide de cada valor dentro da Serie.
titanic_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
round(titanic_df['Pclass'].value_counts(normalize=True),2)
# Out:
# 3    0.55
# 1    0.24
# 2    0.21
# Name: Pclass, dtype: float64

# %%
titanic_df['X'] = 1

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#metodo groupby, podemos até comparar ele com o group by do sql. Porém construir com o pandas é bem simples.
titanic_df[['Pclass', 'X']].groupby("Pclass").sum()
# Out:
#           X
# Pclass
# 1       216
# 2       184
# 3       491
