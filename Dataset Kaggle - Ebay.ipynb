# %% [markdown]
# <h3>Dataset Kaggle:
# Automoveis Usados da Alemanha vendidos pelo Ebay</h3>

# %%
#Importando Pandas
import pandas as pd

# %%
#Lendo dataaset de automoveis usados na Alemanha quem estão a venda pelo Ebay
autos_df = pd.read_csv('C:\FCD/autos.csv')

# %%
#Abrindo dataset
autos_df.head(8)
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-24 11:52:17                                         Golf_3_1.6
# 1  2016-03-23 10:58:45                               A5_Sportback_2.7_Tdi
# 2  2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 3  2016-03-17 16:54:04                                 GOLF_4_1_4__3TÜRER
# 4  2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 5  2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 6  2016-04-01 20:48:51                        Peugeot_206_CC_110_Platinum
# 7  2016-03-21 18:54:38                       VW_Derby_Bj_80__Scheunenfund
#
#    seller offerType  price abtest vehicleType  yearOfRegistration    gearbox  \
# 0  privat     Offer    480   test       Other                1993    manuell
# 1  privat     Offer  18300   test       coupe                2011    manuell
# ...

# %%
#Exibir numero de linhas e colunas 
autos_df.shape
# Out:
# (313687, 27)

# %%
#Exibi o numero de colunas do dataset
autos_df.shape[1]
# Out:
# 27

# %%
#Exibi informações estatisticas
autos_df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  313687.000000       313687.000000  313687.000000  313687.000000
# mean     3902.961863         2001.909231     109.564250  131435.778340
# std      4168.150636            6.803211     191.741685   34963.149957
# min         0.000000         1910.000000       0.000000    5000.000000
# 25%       999.000000         1998.000000      68.000000  125000.000000
# 50%      2490.000000         2002.000000     104.000000  150000.000000
# 75%      5400.000000         2006.000000     140.000000  150000.000000
# max     28800.000000         2016.000000   20000.000000  150000.000000
#
#           postalCode  yearOfCreation  yearCrawled  NoOfDaysOnline  \
# count  313687.000000   313687.000000     313687.0   313687.000000
# mean    50349.563597     2015.999930       2016.0        8.543274
# std     25765.545682        0.008374          0.0        8.511917
# ...

# %%
#mostra a porcentagem de dados nulos
round((autos_df.isnull().sum() * 100) / autos_df.shape[0],2)
# Out:
# dateCrawled            0.00
# name                   0.00
# seller                 0.00
# offerType              0.00
# price                  0.00
# abtest                 0.00
# vehicleType            0.00
# yearOfRegistration     0.00
# gearbox                0.00
# powerPS                0.00
# model                  0.00
# kilometer              0.00
# monthOfRegistration    0.00
# fuelType               0.06
# brand                  0.00
# notRepairedDamage      0.00
# dateCreated            0.00
# postalCode             0.00
# lastSeen               0.00
# yearOfCreation         0.00
# yearCrawled            0.00
# monthOfCreation        0.00
# monthCrawled           0.00
# NoOfDaysOnline         0.00
# NoOfHrsOnline          0.00
# yearsOld               0.00
# monthsOld              0.00
# dtype: float64

# %%
#mostra a porcentagem de dados NA
autos_df.isna().sum()
# Out:
# dateCrawled              0
# name                     0
# seller                   0
# offerType                0
# price                    0
# abtest                   0
# vehicleType              0
# yearOfRegistration       0
# gearbox                  0
# powerPS                  0
# model                    0
# kilometer                0
# monthOfRegistration      0
# fuelType               189
# brand                    0
# notRepairedDamage        0
# dateCreated              0
# postalCode               0
# lastSeen                 0
# yearOfCreation           0
# yearCrawled              0
# monthOfCreation          0
# monthCrawled             0
# NoOfDaysOnline           0
# NoOfHrsOnline            0
# yearsOld                 0
# monthsOld                0
# dtype: int64

# %%
#Exibi os dados apartir da linha 700 a 750
autos_df.loc[700:750]
# Out:
#              dateCrawled                                               name  \
# 700  2016-03-09 20:38:22  Opel_Omega_2_0_116PS_TÜV_04/2016_Neue_Bremsen_...
# 701  2016-03-05 20:36:24                                           BMW_320i
# 702  2016-03-23 19:00:20                     Opel_Astra_2.0_16V_Turbo_Coupe
# 703  2016-03-23 22:49:45                         Mercedes_benz_s320_tip_top
# 704  2016-03-09 10:54:10                         Honda_Accord_2.0_i_Comfort
# 705  2016-03-25 11:50:46                              Audi_A4_Cabriolet_2.4
# 706  2016-03-19 10:51:07                         diesel_sparbuechse_corsa_c
# 707  2016-04-02 16:49:46          Audi_A4_1.8_T_AHK__Xenon__Navi__gepflegt!
# 708  2016-03-17 14:38:54   Ford_Focus_Turnier_1.6_TDCi_bis_18.03_angemeldet
# 709  2016-03-26 16:53:56                              Polo_9n3_ah_exclusive
# 710  2016-03-11 12:54:22  VW_GOLF_4_1.4_16V_TÜV_NEU_KLIMA_4X_ELEKTRIK_FE...
# ...

# %%
#criando um novo dataframe com as seguintes tabelas
novoautos_df = autos_df [['name','price','vehicleType', 'yearOfRegistration', 'gearbox']]

# %%
#mostra o novo dataframe criado com as tabelas selecionadas
novoautos_df.head(15)
# Out:
#                                                  name  price vehicleType  \
# 0                                          Golf_3_1.6    480       Other
# 1                                A5_Sportback_2.7_Tdi  18300       coupe
# 2                      Jeep_Grand_Cherokee_"Overland"   9800         suv
# 3                                  GOLF_4_1_4__3TÜRER   1500  kleinwagen
# 4                      Skoda_Fabia_1.4_TDI_PD_Classic   3600  kleinwagen
# 5   BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650   limousine
# 6                         Peugeot_206_CC_110_Platinum   2200      cabrio
# 7                        VW_Derby_Bj_80__Scheunenfund      0   limousine
# 8   VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...    999  kleinwagen
# 9                                   Mazda_3_1.6_Sport   2000   limousine
# 10      Volkswagen_Passat_Variant_2.0_TDI_Comfortline   2799       kombi
# 11                  VW_Passat_Facelift_35i__"7Sitzer"    999       kombi
# ...
